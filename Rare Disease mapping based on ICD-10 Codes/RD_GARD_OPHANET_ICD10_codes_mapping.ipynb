# %% [markdown]
# # Rare disease patients mapping to EHR system by using ICD-10 codes
# #### (Rare Disease Data Preprocessing (GARD-ORPHANET) ICD10 codes to use it in N3C enclave)
# This notebbok is to get concept ids (ICD-10 codes) of rare diseases. We used 12,003 rare diseases from GARD (https://rarediseases.info.nih.gov/) and mapped it to ORPHANET (https://www.orpha.net/) which mapped 9369 ORPHANET codes. Further we used folloing inclusion/exclusion criterias:
#  - Excluded groups of disorders
#  - Dropped ICD-10 codes if it has phenotype mapping
#
# This file is a parsing from these three files:
# 1. RDIP's Disease List for GARD-Orphanet mappings
# 2. Orphanet via Orphadata (see here) - July 2023 version releases
#
#     a. Product 1 for Orphanet entities, Names, Classification Levels, and Xrefs to ICD-10 (note that this is ICD-10 and is not the US-version, ICD-10-CM)
#
#     b. Orphanet-SNOMED Mappings for Xrefs to SNOMED

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## GARD-ORPHANET-MAPPING files

# %%
# Following file (Orphanet via Orphadata - July 2023 version releases) converted xml to xlsx file
# This first sheet of the file
ICD10 = pd.read_excel('C:\\Users\\,...,\\RD_Cohort_Paper_Feb_2025\\GARD-Orphanet-SNOMED+ICD10_2023-11-29.xlsx',sheet_name = 'en_product1', engine='openpyxl' )
print('DataFrame_size', ICD10.shape)
ICD10.head()
# Out:
# DataFrame_size (78021, 85)
#               /JDBOR           Unnamed: 1  \
# 0        /@copyright               /@date
# 1  Orphanet (c) 2023  2023-06-22 13:48:49
# 2  Orphanet (c) 2023  2023-06-22 13:48:49
# 3  Orphanet (c) 2023  2023-06-22 13:48:49
# 4  Orphanet (c) 2023  2023-06-22 13:48:49
#
#                               Unnamed: 2  \
# 0                             /@dbserver
# 1  jdbc:sybase:Tds:canard.orpha.net:2020
# 2  jdbc:sybase:Tds:canard.orpha.net:2020
# 3  jdbc:sybase:Tds:canard.orpha.net:2020
# 4  jdbc:sybase:Tds:canard.orpha.net:2020
#
#                                        Unnamed: 3  \
# 0                                       /@version
# 1  1.3.25 / 4.1.7 [2023-04-17] (orientdb version)
# 2  1.3.25 / 4.1.7 [2023-04-17] (orientdb version)
# 3  1.3.25 / 4.1.7 [2023-04-17] (orientdb version)
# 4  1.3.25 / 4.1.7 [2023-04-17] (orientdb version)
#
#                                        Unnamed: 4  \
# 0                  /Availability/Licence/FullName
# 1  Creative Commons Attribution 4.0 International
# 2  Creative Commons Attribution 4.0 International
# 3  Creative Commons Attribution 4.0 International
# 4  Creative Commons Attribution 4.0 International
#
#                              Unnamed: 5  \
# 0  /Availability/Licence/FullName/@lang
# 1                                    en
# 2                                    en
# 3                                    en
# 4                                    en
#
#                                           Unnamed: 6  \
# 0                    /Availability/Licence/LegalCode
# 1  https://creativecommons.org/licenses/by/4.0/le...
# 2  https://creativecommons.org/licenses/by/4.0/le...
# 3  https://creativecommons.org/licenses/by/4.0/le...
# 4  https://creativecommons.org/licenses/by/4.0/le...
#
#                               Unnamed: 7            Unnamed: 8  \
# 0  /Availability/Licence/ShortIdentifier  /DisorderList/@count
# 1                              CC-BY-4.0                 10839
# 2                              CC-BY-4.0                 10839
# 3                              CC-BY-4.0                 10839
# 4                              CC-BY-4.0                 10839
#
#                    Unnamed: 9  ...  \
# 0  /DisorderList/Disorder/#id  ...
# 1                           1  ...
# 2                           1  ...
# 3                           1  ...
# 4                           1  ...
#
#                                          Unnamed: 75  \
# 0  /DisorderList/Disorder/SummaryInformationList/...
# 1                                              83697
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Unnamed: 76  \
# 0  /DisorderList/Disorder/SummaryInformationList/...
# 1                                                 en
# 2                                                 en
# 3                                                 en
# 4                                                 en
#
#                                          Unnamed: 77  \
# 0  /DisorderList/Disorder/SummaryInformationList/...
# 1  A rare primary bone dysplasia characterized by...
# 2  A rare primary bone dysplasia characterized by...
# 3  A rare primary bone dysplasia characterized by...
# 4  A rare primary bone dysplasia characterized by...
#
#                                          Unnamed: 78  \
# 0  /DisorderList/Disorder/SummaryInformationList/...
# 1                                              16907
# 2                                              16907
# 3                                              16907
# 4                                              16907
#
#                                          Unnamed: 79  \
# 0  /DisorderList/Disorder/SummaryInformationList/...
# 1                                              16907
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Unnamed: 80  \
# 0  /DisorderList/Disorder/SummaryInformationList/...
# 1                                         Definition
# 2                                         Definition
# 3                                         Definition
# 4                                         Definition
#
#                                          Unnamed: 81  \
# 0  /DisorderList/Disorder/SummaryInformationList/...
# 1                                                 en
# 2                                                 en
# 3                                                 en
# 4                                                 en
#
#                                  Unnamed: 82  \
# 0  /DisorderList/Disorder/SynonymList/@count
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#                                   Unnamed: 83  \
# 0  /DisorderList/Disorder/SynonymList/Synonym
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                                         Unnamed: 84
# 0  /DisorderList/Disorder/SynonymList/Synonym/@lang
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
# [5 rows x 85 columns]

# %%
# GARD to ORPHANET mapping file (out of 12004 rare diseases only 9369 rare disease mapped from GARD to ORPHANET)
GARD_to_Orphanet = pd.read_excel('C:\\Users\\,...,\\RD_Cohort_Paper_Feb_2025\\GARD-Orphanet-SNOMED+ICD10_2023-11-29.xlsx',sheet_name = 'GARD-to-Orphanet' , engine='openpyxl')
print('GARD_to_Orphanet_DataFrame_size', GARD_to_Orphanet.shape)
GARD_to_Orphanet.head()
# Out:
# GARD_to_Orphanet_DataFrame_size (9369, 6)
#    GardID DataSource  SourceID  ClassificationLevel             DisorderType  \
# 0      69   Orphanet    319247             Disorder                [Disease]
# 1      86   Orphanet    314597             Disorder  [Malformation syndrome]
# 2      73   Orphanet    101088  Subtype of disorder       [Clinical subtype]
# 3      79   Orphanet     33067             Disorder                [Disease]
# 4       6   Orphanet     93437   Group of disorders         [Clinical group]
#
#                                   SourceName
# 0              Hantavirus pulmonary syndrome
# 1                Chudley-McCullough syndrome
# 2                X-linked hyper-IgM syndrome
# 3  Metaphyseal chondrodysplasia, Jansen type
# 4                    Acromesomelic dysplasia

# %%
# selected columns which is relevent to ICD10 codes sorting
ICD10  = ICD10[['Unnamed: 37','Unnamed: 53','Unnamed: 59','Unnamed: 60','Unnamed: 61','Unnamed: 63']]
# renamed selected columns
ICD10.rename(columns = {'Unnamed: 37':'DisorderGroup','Unnamed: 53': 'DisorderMappingRelation','Unnamed: 59' : 'code', 'Unnamed: 60' : 'code_classification', 'Unnamed: 61' : 'name', 'Unnamed: 63' : 'OrphaCode'}, inplace = True)
# dropping 1st column which is columns header
data_orpha = ICD10.iloc[1:]
data_orpha
# Out:
#             DisorderGroup                            DisorderMappingRelation  \
# 1                Disorder                                                NaN
# 2                Disorder                                                NaN
# 3                Disorder  NTBT (ORPHAcode is narrower than the targeted ...
# 4                Disorder  NTBT (ORPHAcode is narrower than the targeted ...
# 5                Disorder  E (Exact mapping: the two concepts are equival...
# ...                   ...                                                ...
# 78016            Disorder                                                NaN
# 78017  Group of disorders                                                NaN
# 78018  Group of disorders                                                NaN
# 78019  Group of disorders                                                NaN
# 78020  Group of disorders                                                NaN
#
#           code code_classification  \
# 1          NaN                 NaN
# 2          NaN                 NaN
# 3      LD24.61              ICD-11
# 4        Q77.3              ICD-10
# 5       607131                OMIM
# ...        ...                 ...
# 78016      NaN                 NaN
# 78017      NaN                 NaN
# 78018      NaN                 NaN
# 78019      NaN                 NaN
# 78020      NaN                 NaN
#
#                                                     name OrphaCode
# 1          Multiple epiphyseal dysplasia, Al-Gazali type    166024
# 2          Multiple epiphyseal dysplasia, Al-Gazali type    166024
# 3          Multiple epiphyseal dysplasia, Al-Gazali type    166024
# 4          Multiple epiphyseal dysplasia, Al-Gazali type    166024
# 5          Multiple epiphyseal dysplasia, Al-Gazali type    166024
# ...                                                  ...       ...
# 78016  Hereditary persistence of fetal hemoglobin-int...    619233
# 78017           Rare hereditary autoinflammatory disease    619238
# 78018           Rare hereditary autoinflammatory disease    619238
# 78019           Rare hereditary autoinflammatory disease    619238
# 78020           Rare hereditary autoinflammatory disease    619238
#
# [78020 rows x 6 columns]

# %%
# dropping 1st column which is columns header
data_orpha = ICD10.iloc[1:]
data_orpha
# Out:
#             DisorderGroup                            DisorderMappingRelation  \
# 1                Disorder                                                NaN
# 2                Disorder                                                NaN
# 3                Disorder  NTBT (ORPHAcode is narrower than the targeted ...
# 4                Disorder  NTBT (ORPHAcode is narrower than the targeted ...
# 5                Disorder  E (Exact mapping: the two concepts are equival...
# ...                   ...                                                ...
# 78016            Disorder                                                NaN
# 78017  Group of disorders                                                NaN
# 78018  Group of disorders                                                NaN
# 78019  Group of disorders                                                NaN
# 78020  Group of disorders                                                NaN
#
#           code code_classification  \
# 1          NaN                 NaN
# 2          NaN                 NaN
# 3      LD24.61              ICD-11
# 4        Q77.3              ICD-10
# 5       607131                OMIM
# ...        ...                 ...
# 78016      NaN                 NaN
# 78017      NaN                 NaN
# 78018      NaN                 NaN
# 78019      NaN                 NaN
# 78020      NaN                 NaN
#
#                                                     name OrphaCode
# 1          Multiple epiphyseal dysplasia, Al-Gazali type    166024
# 2          Multiple epiphyseal dysplasia, Al-Gazali type    166024
# 3          Multiple epiphyseal dysplasia, Al-Gazali type    166024
# 4          Multiple epiphyseal dysplasia, Al-Gazali type    166024
# 5          Multiple epiphyseal dysplasia, Al-Gazali type    166024
# ...                                                  ...       ...
# 78016  Hereditary persistence of fetal hemoglobin-int...    619233
# 78017           Rare hereditary autoinflammatory disease    619238
# 78018           Rare hereditary autoinflammatory disease    619238
# 78019           Rare hereditary autoinflammatory disease    619238
# 78020           Rare hereditary autoinflammatory disease    619238
#
# [78020 rows x 6 columns]

# %%
# Merged GARD to Orphanet maping file with Orphanet to ICD10 code file
merged_df = pd.merge(data_orpha, GARD_to_Orphanet, how = 'inner', left_on = 'OrphaCode', right_on = 'SourceID')
# select relevant columns
data_orpha_Gard = merged_df[['DisorderGroup', 'DisorderMappingRelation', 'code','code_classification', 'name', 'OrphaCode','GardID']]
data_orpha_Gard
# Out:
#       DisorderGroup                            DisorderMappingRelation  \
# 0          Disorder                                                NaN
# 1          Disorder                                                NaN
# 2          Disorder  NTBT (ORPHAcode is narrower than the targeted ...
# 3          Disorder  NTBT (ORPHAcode is narrower than the targeted ...
# 4          Disorder  E (Exact mapping: the two concepts are equival...
# ...             ...                                                ...
# 69458      Disorder                                                NaN
# 69459      Disorder                                                NaN
# 69460      Disorder  NTBT (ORPHAcode is narrower than the targeted ...
# 69461      Disorder  E (Exact mapping: the two concepts are equival...
# 69462      Disorder                                                NaN
#
#           code code_classification  \
# 0          NaN                 NaN
# 1          NaN                 NaN
# 2      LD24.61              ICD-11
# 3        Q77.3              ICD-10
# 4       607131                OMIM
# ...        ...                 ...
# 69458      NaN                 NaN
# 69459      NaN                 NaN
# 69460    Q87.8              ICD-10
# 69461   617101                OMIM
# 69462      NaN                 NaN
#
#                                                     name OrphaCode  GardID
# 0          Multiple epiphyseal dysplasia, Al-Gazali type    166024   17014
# 1          Multiple epiphyseal dysplasia, Al-Gazali type    166024   17014
# 2          Multiple epiphyseal dysplasia, Al-Gazali type    166024   17014
# 3          Multiple epiphyseal dysplasia, Al-Gazali type    166024   17014
# 4          Multiple epiphyseal dysplasia, Al-Gazali type    166024   17014
# ...                                                  ...       ...     ...
# 69458  Hereditary persistence of fetal hemoglobin-int...    619233   22458
# 69459  Hereditary persistence of fetal hemoglobin-int...    619233   22458
# 69460  Hereditary persistence of fetal hemoglobin-int...    619233   22458
# 69461  Hereditary persistence of fetal hemoglobin-int...    619233   22458
# 69462  Hereditary persistence of fetal hemoglobin-int...    619233   22458
#
# [69463 rows x 7 columns]

# %%
# Selecting 'Exact mapping: the two concepts are equivalent' match between two files
data_orpha_new = data_orpha_Gard[data_orpha_Gard['DisorderMappingRelation'] == 'E (Exact mapping: the two concepts are equivalent)']
data_orpha_new
# Out:
#       DisorderGroup                            DisorderMappingRelation  \
# 4          Disorder  E (Exact mapping: the two concepts are equival...
# 5          Disorder  E (Exact mapping: the two concepts are equival...
# 9          Disorder  E (Exact mapping: the two concepts are equival...
# 10         Disorder  E (Exact mapping: the two concepts are equival...
# 11         Disorder  E (Exact mapping: the two concepts are equival...
# ...             ...                                                ...
# 69338      Disorder  E (Exact mapping: the two concepts are equival...
# 69397      Disorder  E (Exact mapping: the two concepts are equival...
# 69430      Disorder  E (Exact mapping: the two concepts are equival...
# 69434      Disorder  E (Exact mapping: the two concepts are equival...
# 69461      Disorder  E (Exact mapping: the two concepts are equival...
#
#            code code_classification  \
# 4        607131                OMIM
# 5      C1846722                UMLS
# 9        203450                OMIM
# 10      D038261                MeSH
# 11     C0270726                UMLS
# ...         ...                 ...
# 69338    618618                OMIM
# 69397  C0346360                UMLS
# 69430  C5680416                UMLS
# 69434    617744                OMIM
# 69461    617101                OMIM
#
#                                                     name OrphaCode  GardID
# 4          Multiple epiphyseal dysplasia, Al-Gazali type    166024   17014
# 5          Multiple epiphyseal dysplasia, Al-Gazali type    166024   17014
# 9                                      Alexander disease        58    5774
# 10                                     Alexander disease        58    5774
# 11                                     Alexander disease        58    5774
# ...                                                  ...       ...     ...
# 69338        MIR140-related spondyloepiphyseal dysplasia    623695   22495
# 69397                    Conjunctival malignant melanoma    617910   10744
# 69430  Early-onset autoimmunity-autoinflammation-immu...    619948   22465
# 69434  Developmental delay-immunodeficiency-leukoence...    619979   22468
# 69461  Hereditary persistence of fetal hemoglobin-int...    619233   22458
#
# [16523 rows x 7 columns]

# %%
# Selecting only ICD10 codes (which is 575 diseases)
data_orpha_ICD10 = data_orpha_new[data_orpha_new['code_classification'] == 'ICD-10']
data_orpha_ICD10
# Out:
#       DisorderGroup                            DisorderMappingRelation   code  \
# 339        Disorder  E (Exact mapping: the two concepts are equival...  D59.5
# 584        Disorder  E (Exact mapping: the two concepts are equival...  Q80.1
# 685        Disorder  E (Exact mapping: the two concepts are equival...  D56.1
# 701        Disorder  E (Exact mapping: the two concepts are equival...  D56.0
# 878        Disorder  E (Exact mapping: the two concepts are equival...  L40.3
# ...             ...                                                ...    ...
# 68961      Disorder  E (Exact mapping: the two concepts are equival...  K00.0
# 69039      Disorder  E (Exact mapping: the two concepts are equival...  Q35.3
# 69046      Disorder  E (Exact mapping: the two concepts are equival...  Q35.7
# 69067      Disorder  E (Exact mapping: the two concepts are equival...  L92.2
# 69120      Disorder  E (Exact mapping: the two concepts are equival...  O88.1
#
#       code_classification                                 name OrphaCode  \
# 339                ICD-10  Paroxysmal nocturnal hemoglobinuria       447
# 584                ICD-10        Recessive X-linked ichthyosis       461
# 685                ICD-10                     Beta-thalassemia       848
# 701                ICD-10                    Alpha-thalassemia       846
# 878                ICD-10     Pustulosis palmaris et plantaris    163927
# ...                   ...                                  ...       ...
# 68961              ICD-10                            Anodontia     99797
# 69039              ICD-10                          Cleft velum     99772
# 69046              ICD-10                          Bifid uvula     99771
# 69067              ICD-10                    Granuloma faciale    615943
# 69120              ICD-10              Amniotic fluid embolism    617304
#
#        GardID
# 339      7337
# 584      7904
# 685       871
# 701       621
# 878     12820
# ...       ...
# 68961    5818
# 69039   16907
# 69046   19687
# 69067   22442
# 69120   22448
#
# [575 rows x 7 columns]

# %%
data_orpha_ICD10.to_csv('data_orpha_ICD10.csv',index=False, encoding='utf-16-le', sep=',')

# %%
# Number of unique GARD IDs mapped with Orphanet & ICD-10 codes
len(data_orpha_ICD10['GardID'].unique())
# Out:
# 564

# %%
# Drop diseases from if it is a groups of disorders
GARD_Orpha_ICD10_with_group_disorder = data_orpha_ICD10[data_orpha_ICD10['DisorderGroup'] =='Group of disorders']
GARD_Orpha_ICD10_with_group_disorder
# Out:
#             DisorderGroup                            DisorderMappingRelation  \
# 5205   Group of disorders  E (Exact mapping: the two concepts are equival...
# 5384   Group of disorders  E (Exact mapping: the two concepts are equival...
# 5457   Group of disorders  E (Exact mapping: the two concepts are equival...
# 5651   Group of disorders  E (Exact mapping: the two concepts are equival...
# 5757   Group of disorders  E (Exact mapping: the two concepts are equival...
# ...                   ...                                                ...
# 66743  Group of disorders  E (Exact mapping: the two concepts are equival...
# 66944  Group of disorders  E (Exact mapping: the two concepts are equival...
# 66976  Group of disorders  E (Exact mapping: the two concepts are equival...
# 68134  Group of disorders  E (Exact mapping: the two concepts are equival...
# 68619  Group of disorders  E (Exact mapping: the two concepts are equival...
#
#         code code_classification                                       name  \
# 5205     D24              ICD-10                   Rare benign breast tumor
# 5384   Q51.4              ICD-10  Unilateral aplasia of the Müllerian ducts
# 5457   Q51.3              ICD-10                          Bicornuate uterus
# 5651   E85.0              ICD-10                                Amyloidosis
# 5757   C84.0              ICD-10             Mycosis fungoides and variants
# ...      ...                 ...                                        ...
# 66743    D70              ICD-10                 Constitutional neutropenia
# 66944    D81              ICD-10     Combined T and B cell immunodeficiency
# 66976  E23.0              ICD-10                       Pituitary deficiency
# 68134  B87.0              ICD-10                          Cutaneous myiasis
# 68619  E24.0              ICD-10            ACTH-dependent Cushing syndrome
#
#       OrphaCode  GardID
# 5205     180253   12775
# 5384     180071   20173
# 5457     180134   20183
# 5651         69   18676
# 5757     178566   20166
# ...         ...     ...
# 66743    101987   19809
# 66944    101972   19806
# 66976    101957   19801
# 68134     99983   19723
# 68619     99892   19699
#
# [112 rows x 7 columns]

# %%
GARD_Orpha_ICD10_with_group_disorder.to_csv("ICD10_codes_drop_due_to_groups_of_disorders.csv", index = False)

# %% [markdown]
# ### Drop rare diseases GARD IDs if it is group of disorders

# %%
# Drop diseases from if it is a groups of disorders
GARD_Orpha_ICD10_without_group_disorder = data_orpha_ICD10[data_orpha_ICD10['DisorderGroup'] !='Group of disorders']
GARD_Orpha_ICD10_without_group_disorder
# Out:
#       DisorderGroup                            DisorderMappingRelation   code  \
# 339        Disorder  E (Exact mapping: the two concepts are equival...  D59.5
# 584        Disorder  E (Exact mapping: the two concepts are equival...  Q80.1
# 685        Disorder  E (Exact mapping: the two concepts are equival...  D56.1
# 701        Disorder  E (Exact mapping: the two concepts are equival...  D56.0
# 878        Disorder  E (Exact mapping: the two concepts are equival...  L40.3
# ...             ...                                                ...    ...
# 68961      Disorder  E (Exact mapping: the two concepts are equival...  K00.0
# 69039      Disorder  E (Exact mapping: the two concepts are equival...  Q35.3
# 69046      Disorder  E (Exact mapping: the two concepts are equival...  Q35.7
# 69067      Disorder  E (Exact mapping: the two concepts are equival...  L92.2
# 69120      Disorder  E (Exact mapping: the two concepts are equival...  O88.1
#
#       code_classification                                 name OrphaCode  \
# 339                ICD-10  Paroxysmal nocturnal hemoglobinuria       447
# 584                ICD-10        Recessive X-linked ichthyosis       461
# 685                ICD-10                     Beta-thalassemia       848
# 701                ICD-10                    Alpha-thalassemia       846
# 878                ICD-10     Pustulosis palmaris et plantaris    163927
# ...                   ...                                  ...       ...
# 68961              ICD-10                            Anodontia     99797
# 69039              ICD-10                          Cleft velum     99772
# 69046              ICD-10                          Bifid uvula     99771
# 69067              ICD-10                    Granuloma faciale    615943
# 69120              ICD-10              Amniotic fluid embolism    617304
#
#        GardID
# 339      7337
# 584      7904
# 685       871
# 701       621
# 878     12820
# ...       ...
# 68961    5818
# 69039   16907
# 69046   19687
# 69067   22442
# 69120   22448
#
# [463 rows x 7 columns]

# %%
GARD_Orpha_ICD10_without_group_disorder.to_csv('GARD_Orpha_ICD10_without_group_disorder.csv',index=False, encoding='utf-16-le', sep=',')

# %%
GARD_Orpha_ICD10_without_group_disorder['name'].to_csv('ICD10_codes_for_HPO_mapping.txt', sep='\t', index=False, encoding='utf-16-le')

# %% [markdown]
# ### HPO mapping of final diseases list

# %%
import requests
import json
import csv
from urllib.parse import quote

def get_hpo(dis):
    # Remove any null bytes or unwanted characters from the input term
    dis = dis.replace('\x00', '')  # Remove any null characters
    # URL encode the disease term to handle spaces and special characters correctly
    encoded_dis = quote(dis)
    url = f'https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms={encoded_dis}'
    print(url)  # Print the URL for debugging
    my_response = requests.get(url)
    return my_response

# Specify the output CSV file name
output_file_name = "C:\\Users\\,...,\\RD_Cohort_Paper_Feb_2025\\ICD_10_code_mapping\\ICD10_codes_with_HPO_tag.csv"

# Open the output file in write mode with UTF-8 encoding for CSV
with open(output_file_name, 'w', encoding='utf-16-le', newline='') as output_file:
    # Create a CSV writer
    csv_writer = csv.writer(output_file)
    
    # Write the header row (optional, but useful to name the columns)
    csv_writer.writerow(["name", "HPO"])
    
    # Open the input file in read mode with a different encoding (ISO-8859-1 or latin1)
    with open('C:\\Users\\,...,\\RD_Cohort_Paper_Feb_2025\\ICD_10_code_mapping\\ICD10_codes_for_HPO_mapping.txt', 'r', encoding='ISO-8859-1') as input_file:
        lines = input_file.readlines()
        for x in lines:
            # Strip extra spaces and newlines, replace underscores with spaces
            x = x.strip().replace('_', ' ')
            
            # Remove any null characters that might have appeared
            x = x.replace('\x00', '')
            
            # Ensure the disease name is properly handled for spaces and special characters
            print(x)  # Print the disease name (for debugging)
            
            # Call the get_hpo function to retrieve information
            info = get_hpo(x)
            
            if info.ok:
                j_data = json.loads(info.content)
                # For simplicity, you can convert the JSON data to a string (you could format it better if needed)
                hpo_data = json.dumps(j_data)
                # Write the disease name and HPO data to the CSV file
                csv_writer.writerow([x, hpo_data])
# Out:
# name
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=name
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
# Paroxysmal nocturnal hemoglobinuria
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=Paroxysmal%20nocturnal%20hemoglobinuria
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
# Recessive X-linked ichthyosis
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=Recessive%20X-linked%20ichthyosis
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
# Beta-thalassemia
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=Beta-thalassemia
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
# Alpha-thalassemia
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=Alpha-thalassemia
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
# Pustulosis palmaris et plantaris
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=Pustulosis%20palmaris%20et%20plantaris
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
# Rett syndrome
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=Rett%20syndrome
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
# Autosomal recessive polycystic kidney disease
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=Autosomal%20recessive%20polycystic%20kidney%20disease
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
# Marfan syndrome
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=Marfan%20syndrome
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
# Huntington disease
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=Huntington%20disease
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
# 22q11.2 deletion syndrome
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=22q11.2%20deletion%20syndrome
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
# Retinoblastoma
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=Retinoblastoma
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
# Fragile X syndrome
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=Fragile%20X%20syndrome
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
# Mucopolysaccharidosis type 2
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=Mucopolysaccharidosis%20type%202
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
# Mucopolysaccharidosis type 1
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=Mucopolysaccharidosis%20type%201
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
#
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
# Anodontia
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=Anodontia
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
# Cleft velum
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=Cleft%20velum
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
# Bifid uvula
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=Bifid%20uvula
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
# Granuloma faciale
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=Granuloma%20faciale
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
# Amniotic fluid embolism
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=Amniotic%20fluid%20embolism
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=
#
# https://clinicaltables.nlm.nih.gov/api/hpo/v3/search?terms=

# %% [markdown]
# #### Following code can be used to save directly in csv file few names character show issue in this approach

# %% [markdown]
# ### import rare disease HPO mapping file

# %%
## HPO mapping of Rare Disease lists (ICD10 /SNOMED-CT codes) 
ICD10_HPO = pd.read_csv('ICD10_codes_with_HPO_tag.csv', encoding='utf-16-le')
print('shape of dataframe', ICD10_HPO.shape)
ICD10_HPO
# Out:
# shape of dataframe (929, 2)
#                                     name  \
# 0                                   name
# 1                                    NaN
# 2    Paroxysmal nocturnal hemoglobinuria
# 3                                    NaN
# 4          Recessive X-linked ichthyosis
# ..                                   ...
# 924                    Granuloma faciale
# 925                                  NaN
# 926              Amniotic fluid embolism
# 927                                  NaN
# 928                                  NaN
#
#                                                    HPO
# 0                                    [0, [], null, []]
# 1    [19434, ["HP:0000001", "HP:0000002", "HP:00000...
# 2    [1, ["HP:0004818"], null, [["HP:0004818", "Par...
# 3    [19434, ["HP:0000001", "HP:0000002", "HP:00000...
# 4                                    [0, [], null, []]
# ..                                                 ...
# 924                                  [0, [], null, []]
# 925  [19434, ["HP:0000001", "HP:0000002", "HP:00000...
# 926                                  [0, [], null, []]
# 927  [19434, ["HP:0000001", "HP:0000002", "HP:00000...
# 928  [19434, ["HP:0000001", "HP:0000002", "HP:00000...
#
# [929 rows x 2 columns]

# %%
# Drop the first row (usually the header or an unwanted entry)
ICD10_HPO = ICD10_HPO.iloc[1:].reset_index(drop=True)

# Drop rows where 'Disease Name' column has NaN values
ICD10_HPO = ICD10_HPO.dropna(subset=["name"])
ICD10_HPO
# Out:
#                                     name  \
# 1    Paroxysmal nocturnal hemoglobinuria
# 3          Recessive X-linked ichthyosis
# 5                       Beta-thalassemia
# 7                      Alpha-thalassemia
# 9       Pustulosis palmaris et plantaris
# ..                                   ...
# 917                            Anodontia
# 919                          Cleft velum
# 921                          Bifid uvula
# 923                    Granuloma faciale
# 925              Amniotic fluid embolism
#
#                                                    HPO
# 1    [1, ["HP:0004818"], null, [["HP:0004818", "Par...
# 3                                    [0, [], null, []]
# 5                                    [0, [], null, []]
# 7                                    [0, [], null, []]
# 9    [1, ["HP:0100847"], null, [["HP:0100847", "Pal...
# ..                                                 ...
# 917  [4, ["HP:0000674", "HP:0000706", "HP:0000677",...
# 919  [2, ["HP:0000185", "HP:0011819"], null, [["HP:...
# 921  [1, ["HP:0000193"], null, [["HP:0000193", "Bif...
# 923                                  [0, [], null, []]
# 925                                  [0, [], null, []]
#
# [463 rows x 2 columns]

# %%
# Following disease mapped with HPO and hence will be dropped from ICD10 code list
ICD10_code_hpo = ICD10_HPO[ICD10_HPO['HPO'] != '[0, [], null, []]' ]
ICD10_code_hpo
# Out:
#                                     name  \
# 1    Paroxysmal nocturnal hemoglobinuria
# 9       Pustulosis palmaris et plantaris
# 21                        Retinoblastoma
# 31              Wiskott-Aldrich syndrome
# 47                   Lamellar ichthyosis
# ..                                   ...
# 879           Congenital mitral stenosis
# 885                    Cleft hard palate
# 917                            Anodontia
# 919                          Cleft velum
# 921                          Bifid uvula
#
#                                                    HPO
# 1    [1, ["HP:0004818"], null, [["HP:0004818", "Par...
# 9    [1, ["HP:0100847"], null, [["HP:0100847", "Pal...
# 21   [1, ["HP:0009919"], null, [["HP:0009919", "Ret...
# 31   [1, ["HP:6000472"], null, [["HP:6000472", "Dec...
# 47   [1, ["HP:0007479"], null, [["HP:0007479", "Con...
# ..                                                 ...
# 879  [1, ["HP:0011570"], null, [["HP:0011570", "Con...
# 885  [6, ["HP:0410005", "HP:0000176", "HP:5201003",...
# 917  [4, ["HP:0000674", "HP:0000706", "HP:0000677",...
# 919  [2, ["HP:0000185", "HP:0011819"], null, [["HP:...
# 921  [1, ["HP:0000193"], null, [["HP:0000193", "Bif...
#
# [106 rows x 2 columns]

# %%
ICD10_code_hpo.to_csv('ICD10_codes_drop_due_to_HPO.csv', index = False, encoding='utf-16-le')

# %%
# Following disease without HPO 
ICD10_code_without_hpo = ICD10_HPO[ICD10_HPO['HPO'] == '[0, [], null, []]' ]
ICD10_code_without_hpo
# Out:
#                                               name                HPO
# 3                    Recessive X-linked ichthyosis  [0, [], null, []]
# 5                                 Beta-thalassemia  [0, [], null, []]
# 7                                Alpha-thalassemia  [0, [], null, []]
# 11                                   Rett syndrome  [0, [], null, []]
# 13   Autosomal recessive polycystic kidney disease  [0, [], null, []]
# ..                                             ...                ...
# 911                Crimean-Congo hemorrhagic fever  [0, [], null, []]
# 913                                    Lassa fever  [0, [], null, []]
# 915                      Marburg hemorrhagic fever  [0, [], null, []]
# 923                              Granuloma faciale  [0, [], null, []]
# 925                        Amniotic fluid embolism  [0, [], null, []]
#
# [357 rows x 2 columns]

# %%
ICD10_code_without_hpo.to_csv('RD_icd10_without_hpo.csv',index=False, encoding='utf-16-le', sep=',')

# %%
icd10_code_without_hpo = pd.read_csv('RD_icd10_without_hpo.csv', encoding='utf-16-le')
icd10_code_without_hpo
# Out:
#                                               name                HPO
# 0                    Recessive X-linked ichthyosis  [0, [], null, []]
# 1                                 Beta-thalassemia  [0, [], null, []]
# 2                                Alpha-thalassemia  [0, [], null, []]
# 3                                    Rett syndrome  [0, [], null, []]
# 4    Autosomal recessive polycystic kidney disease  [0, [], null, []]
# ..                                             ...                ...
# 352                Crimean-Congo hemorrhagic fever  [0, [], null, []]
# 353                                    Lassa fever  [0, [], null, []]
# 354                      Marburg hemorrhagic fever  [0, [], null, []]
# 355                              Granuloma faciale  [0, [], null, []]
# 356                        Amniotic fluid embolism  [0, [], null, []]
#
# [357 rows x 2 columns]

# %%
GARD_Orpha_ICD10_without_group_disorder = pd.read_csv('GARD_Orpha_ICD10_without_group_disorder.csv', encoding='utf-16-le')
GARD_Orpha_ICD10_without_group_disorder
# Out:
#     DisorderGroup                            DisorderMappingRelation   code  \
# 0        Disorder  E (Exact mapping: the two concepts are equival...  D59.5
# 1        Disorder  E (Exact mapping: the two concepts are equival...  Q80.1
# 2        Disorder  E (Exact mapping: the two concepts are equival...  D56.1
# 3        Disorder  E (Exact mapping: the two concepts are equival...  D56.0
# 4        Disorder  E (Exact mapping: the two concepts are equival...  L40.3
# ..            ...                                                ...    ...
# 458      Disorder  E (Exact mapping: the two concepts are equival...  K00.0
# 459      Disorder  E (Exact mapping: the two concepts are equival...  Q35.3
# 460      Disorder  E (Exact mapping: the two concepts are equival...  Q35.7
# 461      Disorder  E (Exact mapping: the two concepts are equival...  L92.2
# 462      Disorder  E (Exact mapping: the two concepts are equival...  O88.1
#
#     code_classification                                 name  OrphaCode  \
# 0                ICD-10  Paroxysmal nocturnal hemoglobinuria        447
# 1                ICD-10        Recessive X-linked ichthyosis        461
# 2                ICD-10                     Beta-thalassemia        848
# 3                ICD-10                    Alpha-thalassemia        846
# 4                ICD-10     Pustulosis palmaris et plantaris     163927
# ..                  ...                                  ...        ...
# 458              ICD-10                            Anodontia      99797
# 459              ICD-10                          Cleft velum      99772
# 460              ICD-10                          Bifid uvula      99771
# 461              ICD-10                    Granuloma faciale     615943
# 462              ICD-10              Amniotic fluid embolism     617304
#
#      GardID
# 0      7337
# 1      7904
# 2       871
# 3       621
# 4     12820
# ..      ...
# 458    5818
# 459   16907
# 460   19687
# 461   22442
# 462   22448
#
# [463 rows x 7 columns]

# %%
# Merged rare disease ICD10 code (df1) with ICD10_HPO file on disease name
ICD10_code_with_hpo = pd.merge(GARD_Orpha_ICD10_without_group_disorder,icd10_code_without_hpo, how = 'inner', on = 'name').drop_duplicates()
ICD10_code_with_hpo
# Out:
#     DisorderGroup                            DisorderMappingRelation   code  \
# 0        Disorder  E (Exact mapping: the two concepts are equival...  Q80.1
# 1        Disorder  E (Exact mapping: the two concepts are equival...  D56.1
# 2        Disorder  E (Exact mapping: the two concepts are equival...  D56.0
# 3        Disorder  E (Exact mapping: the two concepts are equival...  F84.2
# 4        Disorder  E (Exact mapping: the two concepts are equival...  Q61.1
# ..            ...                                                ...    ...
# 368      Disorder  E (Exact mapping: the two concepts are equival...  A98.0
# 369      Disorder  E (Exact mapping: the two concepts are equival...  A96.2
# 370      Disorder  E (Exact mapping: the two concepts are equival...  A98.3
# 371      Disorder  E (Exact mapping: the two concepts are equival...  L92.2
# 372      Disorder  E (Exact mapping: the two concepts are equival...  O88.1
#
#     code_classification                                           name  \
# 0                ICD-10                  Recessive X-linked ichthyosis
# 1                ICD-10                               Beta-thalassemia
# 2                ICD-10                              Alpha-thalassemia
# 3                ICD-10                                  Rett syndrome
# 4                ICD-10  Autosomal recessive polycystic kidney disease
# ..                  ...                                            ...
# 368              ICD-10                Crimean-Congo hemorrhagic fever
# 369              ICD-10                                    Lassa fever
# 370              ICD-10                      Marburg hemorrhagic fever
# 371              ICD-10                              Granuloma faciale
# 372              ICD-10                        Amniotic fluid embolism
#
#      OrphaCode  GardID                HPO
# 0          461    7904  [0, [], null, []]
# 1          848     871  [0, [], null, []]
# 2          846     621  [0, [], null, []]
# 3          778    5696  [0, [], null, []]
# 4          731    8378  [0, [], null, []]
# ..         ...     ...                ...
# 368      99827   19690  [0, [], null, []]
# 369      99824   19688  [0, [], null, []]
# 370      99826    9444  [0, [], null, []]
# 371     615943   22442  [0, [], null, []]
# 372     617304   22448  [0, [], null, []]
#
# [357 rows x 8 columns]

# %%
len(ICD10_code_with_hpo['code'].unique())
# Out:
# 357

# %%
len(ICD10_code_with_hpo['GardID'].unique())
# Out:
# 349

# %%
ICD10_code_with_hpo.to_csv('Final_ICD10_codes_for_N3C_mapping.csv', index = False, encoding='utf-16-le')

# %%
# Following list of ICD-10 codes to map N3C enclave (Any EHR System)
print(ICD10_code_with_hpo['code'].tolist() )
# Out:
# ['Q80.1', 'D56.1', 'D56.0', 'F84.2', 'Q61.1', 'Q87.4', 'G10', 'D82.1', 'Q99.2', 'E76.1', 'E76.0', 'L93.1', 'Q77.4', 'Q16.3', 'M61.1', 'E79.1', 'Q77.5', 'I78.0', 'E80.5', 'K22.0', 'C45.1', 'F84.3', 'Q98.5', 'D47.5', 'G60.1', 'Q82.3', 'G90.1', 'Q23.4', 'Q86.0', 'Q12.1', 'Q77.1', 'P35.0', 'Q83.0', 'Q83.1', 'Q31.5', 'Q31.0', 'C57.0', 'Q51.0', 'Q51.5', 'P37.1', 'P35.8', 'C82.6', 'M35.2', 'M33.2', 'Q78.0', 'T88.3', 'D81.5', 'G70.0', 'Q85.1', 'M31.0+', 'N08.5*', 'M30.1', 'M31.7', 'M31.3', 'B75', 'E71.0', 'Q61.2', 'Q21.1', 'A54.3+', 'H13.1*', 'M31.4', 'A48.1', 'L10.0', 'F84.1', 'M30.3', 'Q99.0', 'E80.3', 'M72.2', 'E24.1', 'G40.8', 'K75.4', 'K74.3', 'L13.0', 'A05.1', 'L44.0', 'Q31.3', 'M91.1', 'G23.1', 'Q99.1', 'J63.2', 'Q97.0', 'D82.2', 'Q77.0', 'K03.5', 'P91.6', 'M11.1', 'Q16.1', 'Q01.1', 'Q31.1', 'Q78.3', 'Q06.2', 'U04.9', 'Q86.1', 'P35.1', 'D76.2', 'G23.0', 'Q72.4', 'O14.2', 'Q78.4', 'L40.1', 'G51.2', 'Q80.3', 'Q80.4', 'L81.3', 'O01.1', 'O01.0', 'I67.5', 'E31.0', 'Q06.0', 'Q44.6', 'L98.2', 'Q04.1', 'Q04.4', 'D81.7', 'B00.4+', 'G05.1*', 'D58.0', 'Q82.1', 'Q78.6', 'H20.2', 'B73', 'B83.0', 'H49.4', 'Q33.2', 'Q22.1', 'A81.2', 'M30.0', 'A69.0', 'A98.5+', 'N08.0*', 'Q23.0', 'Q24.4', 'I27.0', 'Q21.4', 'B81.0', 'P74.5', 'G37.1', 'G14', 'G23.3', 'D80.0', 'Q76.1', 'G37.5', 'G24.1', 'G47.4', 'M35.1', 'D56.2', 'M32.0', 'A07.0', 'D47.3', 'G93.2', 'D80.4', 'L57.1', 'T56.0', 'T56.1', 'M12.4', 'D68.1', 'M86.3', 'A98.2', 'A98.1', 'B33.4+', 'J17.1*', 'A92.4', 'A96.1', 'A98.4', 'A96.0', 'E85.4', 'K13.5', 'Q72.1', 'Q71.2', 'Q71.1', 'Q72.2', 'Q72.0', 'Q71.0', 'B74.4', 'B74.3', 'M06.1', 'B72', 'G04.1', 'M35.0', 'Q45.2', 'T57.2', 'C84.6', 'C84.7', 'T66', 'C90.1', 'Q39.2', 'T63.0', 'A92.5', 'T63.2', 'T65.0', 'B17.0', 'A31.0', 'P94.0', 'M87.2', 'M87.0', 'G50.1', 'G96.0', 'D81.3', 'M02.3', 'Q44.2', 'G70.2', 'D61.0', 'D45', 'Q55.5', 'C51.8', 'B70.0', 'B60.0', 'L66.2', 'L66.3', 'B48.5+', 'A07.3', 'B71.0', 'B88.1', 'L98.3', 'L72.2', 'L85.0', 'Q62.2', 'Q64.3', 'M94.1', 'L68.1', 'L66.1', 'O90.3', 'T51.1', 'E23.2', 'G36.0', 'P27.1', 'J80', 'P24.0', 'P22.0', 'K62.7', 'M12.2', 'A79.0', 'A44.0', 'N98.1', 'Q24.6', 'G37.0', 'M92.7', 'M92.6', 'G00.1', 'Q84.3', 'I42.5', 'N30.1', 'A48.3', 'L00', 'I73.1', 'G01*', 'A39.0+', 'L43.1', 'Q61.5', 'M35.6', 'D81.0', 'C88.0', 'D81.6', 'C83.1', 'C88.4', 'E73.0', 'K66.2', 'A28.1', 'L92.1', 'G73.1', 'L95.0', 'L12.3', 'D56.4', 'L13.1', 'H02.3', 'Q12.4', 'T40.5', 'Q11.0', 'Q10.2', 'L95.1', 'L94.0', 'B22.2', 'H90.5', 'C96.8', 'Q72.5', 'Q71.4', 'Q71.5', 'Q72.6', 'Q69.1', 'Q12.0', 'A69.2', 'Q13.3', 'Q81.1', 'L10.1', 'E70.0', 'M08.4', 'M08.2', 'C94.4', 'C92.8', 'C86.4', 'C91.6', 'C86.5', 'C86.2', 'C86.1', 'C86.0', 'A75.3', 'G12.0', 'A75.2', 'A75.0', 'A77.0', 'A79.1', 'M85.4', 'D81.4', 'Q12.3', 'Q43.7', 'G21.3', 'E52', 'E24.0', 'Q27.1', 'L51.2', 'Q22.4', 'Q32.0', 'G21.0', 'M35.3', 'Q64.0', 'M33.0', 'Q26.2', 'Q26.3', 'Q10.1', 'E22.0', 'A48.2', 'A01.0', 'F80.3', 'C92.6', 'C92.5', 'C94.6', 'C92.2', 'C94.3', 'C81.2', 'C81.1', 'C81.3', 'C81.4', 'C86.6', 'D67', 'D60.1', 'D66', 'G23.2', 'Q12.2', 'K52.3', 'E80.1', 'E34.0', 'A39.1+', 'E35.1*', 'C90.3', 'G90.5', 'G90.6', 'A75.1', 'L12+', 'H13.3*', 'A25.1', 'J67.0', 'A25.0', 'A98.0', 'A96.2', 'A98.3', 'L92.2', 'O88.1']

# %% [markdown]
# ### Following diseases dropped from ICD10 code mapping due to Incidence Filter
#  These 8 diseases dropped from the list due to incidence filter after mapping above 357 rare disease ICD10 codes to N3C enclave. These diseases indence rate (> 6/10000) and hence dropped

# %%
## Following seven rare diseases discarded due to incidence filter from above 357 rare dsisease ICD-10 codes which gives final 350 ICD-10 codes 
rd_discard = ['Q21.1','H90.5','M35.3','G50.1','L81.3','E85.4','A31.0','M72.2']
rd_discard
# Out:
# ['Q21.1', 'H90.5', 'M35.3', 'G50.1', 'L81.3', 'E85.4', 'A31.0','M72.2']
